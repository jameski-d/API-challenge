# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
input_data = "cities.csv"
data = pd.read_csv(input_data)
data
# Out:
#                    city  max temperature  latitude  longitude  humidity  \
# 0              meulaboh            77.34      4.14      96.13        86
# 1                 nazas            90.54     25.23    -104.13         6
# 2              lianzhou            65.05     24.78     112.38        82
# 3              khatanga            -0.49     71.97     102.50        88
# 4              lorengau            83.30     -2.02     147.27        69
# ..                  ...              ...       ...        ...       ...
# 553          codrington            57.76    -38.27     141.97        74
# 554            sisimiut            30.74     66.94     -53.67        93
# 555               sitka            44.60     57.05    -135.33        93
# 556    puerto escondido            86.00     15.85     -97.07        79
# 557  havre-saint-pierre            30.20     50.23     -63.60        50
#
#      clouds   wind country        date
# 0       100   2.33      ID  1587074125
# 1        96   2.91      MX  1587074125
# 2         7   1.88      CN  1587074125
# 3         0  11.36      RU  1587074125
# 4        99   2.17      PG  1587074126
# ..      ...    ...     ...         ...
# 553      68  20.27      AU  1587074055
# 554     100  17.72      GL  1587074219
# 555      90   4.70      US  1587074138
# 556       5   6.93      MX  1587074203
# 557      75  27.51      CA  1587074220
#
# [558 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
fig = gmaps.figure()
heatmap_layer = gmaps.heatmap_layer(data[["latitude", "longitude"]],weights=data["humidity"],
                                    max_intensity=55, point_radius=4.0)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
data.rename(columns={"max temperature":"Max_Temperature"}, inplace=True)
warm_data = data[data.Max_Temperature>=70]
ideal_temp = warm_data[warm_data.Max_Temperature<=90]
ideal_temp
ideal_clouds = ideal_temp[ideal_temp.clouds<=20]
ideal_clouds
ideal_humidity = ideal_clouds[ideal_clouds.humidity<=60]
ideal_humidity
ideal_wind = ideal_humidity[ideal_humidity.wind<=7]
hotel_df = ideal_wind
hotel_df
# Out:
#                       city  Max_Temperature  latitude  longitude  humidity  \
# 13                  najran            77.00     17.49      44.13        50
# 140                 kamthi            82.40     21.23      79.20        39
# 157                 laguna            81.00     38.42    -121.42        38
# 266           saint george            73.99     37.10    -113.58        21
# 279             ongandjera            79.45    -17.88      15.07        23
# 297                 ruston            73.40     32.52     -92.64        20
# 318                  avera            72.00     33.19     -82.53        28
# 320        puerto quijarro            76.23    -17.78     -57.77        46
# 353                 taltal            70.52    -25.40     -70.48        59
# 414  mayor pablo lagerenza            81.75    -19.93     -60.77        24
# 480                tambura            77.34      5.60      27.47        48
# 520              henderson            79.00     36.04    -114.98        16
# 522              mongoumba            81.16      3.64      18.59        51
#
#      clouds  wind country        date
# 13        5  6.93      SA  1587073874
# 140      20  3.36      IN  1587074147
# 157       1  4.03      US  1587074150
# 266       1  4.70      US  1587073954
# 279       0  3.62     NaN  1587074175
# 297       1  6.93      US  1587074178
# 318       1  3.36      US  1587074182
# 320       0  4.59      BO  1587074182
# 353       7  6.82      CL  1587074091
# 414       0  5.91      PY  1587074197
# 480       5  2.30      SS  1587074206
# 520       1  3.36      US  1587074212
# 522       5  1.23      CF  1587074213

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df["Hotel_Name"] = "default"
hotel_df
# Out:
# C:\Users\dofwj\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                       city  Max_Temperature  latitude  longitude  humidity  \
# 13                  najran            77.00     17.49      44.13        50
# 140                 kamthi            82.40     21.23      79.20        39
# 157                 laguna            81.00     38.42    -121.42        38
# 266           saint george            73.99     37.10    -113.58        21
# 279             ongandjera            79.45    -17.88      15.07        23
# 297                 ruston            73.40     32.52     -92.64        20
# 318                  avera            72.00     33.19     -82.53        28
# 320        puerto quijarro            76.23    -17.78     -57.77        46
# 353                 taltal            70.52    -25.40     -70.48        59
# 414  mayor pablo lagerenza            81.75    -19.93     -60.77        24
# 480                tambura            77.34      5.60      27.47        48
# 520              henderson            79.00     36.04    -114.98        16
# 522              mongoumba            81.16      3.64      18.59        51
#
#      clouds  wind country        date Hotel_Name
# 13        5  6.93      SA  1587073874    default
# 140      20  3.36      IN  1587074147    default
# 157       1  4.03      US  1587074150    default
# 266       1  4.70      US  1587073954    default
# 279       0  3.62     NaN  1587074175    default
# 297       1  6.93      US  1587074178    default
# 318       1  3.36      US  1587074182    default
# 320       0  4.59      BO  1587074182    default
# 353       7  6.82      CL  1587074091    default
# 414       0  5.91      PY  1587074197    default
# 480       5  2.30      SS  1587074206    default
# 520       1  3.36      US  1587074212    default
# 522       5  1.23      CF  1587074213    default

# %%
lat_lng = []
lat = hotel_df["latitude"]
lng = hotel_df["longitude"]
lat_lng = zip(lat,lng)
print(lat_lng)
# Out:
# <zip object at 0x0000013B1EECD848>

# %%
#removed keyword = cruise after type = hotel
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=17.49,44.13&radius=5000&type=lodging&key={g_key}"
#response = 
response = requests.get(url).json()
response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAAEll5b8RsnPX5qCU-sAJmiDeE-_pHrtGwDLrYHaB3X8YtIyrIEuEppN1DVsbSyUJIzohmEY9COmDLKJ2eJQmOwzmK_jA-mdHtU4GzrNZlDeWGXDGNxV0U7RvcyPcUYperM3yFvWztTWEgvw3byTRQGO6sjGspmZ8nmbk_tKgp1-Y6fMS0-2fFqnEZFUWt1WAae-BkTO112E0p6JWpCTz9Rk8CxYDOOCF5M30oxq--l2-EE_58KqWpgxl4rY8bY8pAgbpJYH_S5LYCY4vaVm6bZcSpeNAUqtxZNdj47LDTqLjyJazgJJ9DSFXlFPY6J1wrIE7U0XuTKJ7Ajt9hylB-Ptxs4F0wbjMiDzlp5cCTxpYIRb-4ho54wgO-pwz-s12rhIQIDTfpIjEF7Vqk-K3X_U6DBoUIqsFV-G8lhbepmF1TGBzuyqPDjI',
#  'results': [{'geometry': {'location': {'lat': 17.4899148, 'lng': 44.1288001},
#     'viewport': {'northeast': {'lat': 17.4911381802915,
#       'lng': 44.1302192802915},
#      'southwest': {'lat': 17.4884402197085, 'lng': 44.1275213197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '042980b386c4346001a632add3ff73954c247ae4',
#    'name': 'محمد هادي ال فطيح',
#    'place_id': 'ChIJRZMb6fzr_hURILNDHAgDpWs',
#    'plus_code': {'compound_code': 'F4QH+XG Najran Saudi Arabia',
#     'global_code': '7H96F4QH+XG'},
#    'reference': 'ChIJRZMb6fzr_hURILNDHAgDpWs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Najran'},
#   {'geometry': {'location': {'lat': 17.4869641, 'lng': 44.1300792},
#     'viewport': {'northeast': {'lat': 17.4883012302915,
#       'lng': 44.13143668029149},
#      'southwest': {'lat': 17.4856032697085, 'lng': 44.12873871970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '5bc4e9cedb950aea05e9fc842ef63344a888b2ad',
#    'name': 'حلاق القمة الذهبية',
#    'place_id': 'ChIJF69kfHbr_hURdOgmredimV4',
#    'plus_code': {'compound_code': 'F4PJ+Q2 Najran Saudi Arabia',
#     'global_code': '7H96F4PJ+Q2'},
#    'reference': 'ChIJF69kfHbr_hURdOgmredimV4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '3721 طريق الملك عبدالعزيز، ابا لسعود، 7626, Najran'},
#   {'geometry': {'location': {'lat': 17.4874784, 'lng': 44.1338262},
#     'viewport': {'northeast': {'lat': 17.4887358302915,
#       'lng': 44.1352365302915},
#      'southwest': {'lat': 17.4860378697085, 'lng': 44.13253856970851}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'c3e6a660637a3b0f11ba4f6528ec0339c13e11cf',
#    'name': 'ام يحيى النقاشة',
#    'place_id': 'ChIJvbrNrRTr_hURbhB816kBwec',
#    'plus_code': {'compound_code': 'F4PM+XG Najran Saudi Arabia',
#     'global_code': '7H96F4PM+XG'},
#    'rating': 5,
#    'reference': 'ChIJvbrNrRTr_hURbhB816kBwec',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '2810، ابا لسعود، نجران 66277 8240،'},
#   {'geometry': {'location': {'lat': 17.4965027, 'lng': 44.1305425},
#     'viewport': {'northeast': {'lat': 17.4979170802915,
#       'lng': 44.1320206802915},
#      'southwest': {'lat': 17.4952191197085, 'lng': 44.1293227197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '6aad920528c0660dbc12894a18cbd5fcc0f9fafe',
#    'name': 'ضيافة آل ياسين',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111015789575340562013">الحسن آل ياسين</a>'],
#      'photo_reference': 'CmRaAAAATQ6Spy-O-HymO074qbk1xLgeLL6tWdjK6IWKI4SA3Qh7fd2Zty_sQi4mFTUnPF3rbjSVjt0CQnB32IWQS1csyG8p_3qW2XRd26skoZEqmJFZvzO1mh5UrVkvG8AKAbevEhBfaPQOC04KHsJ_XGqCK5esGhTHL3BrtiAzRiU4FQ04aTy91TPHxw',
#      'width': 2448}],
#    'place_id': 'ChIJ-7xhOAHr_hURmS2prDs3YjY',
#    'plus_code': {'compound_code': 'F4WJ+J6 Najran Saudi Arabia',
#     'global_code': '7H96F4WJ+J6'},
#    'rating': 4.7,
#    'reference': 'ChIJ-7xhOAHr_hURmS2prDs3YjY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 25,
#    'vicinity': 'Prince Nayif Ibn Abdulaziz, Najran'},
#   {'geometry': {'location': {'lat': 17.4844468, 'lng': 44.1367176},
#     'viewport': {'northeast': {'lat': 17.4863526302915,
#       'lng': 44.1381443802915},
#      'southwest': {'lat': 17.4836546697085, 'lng': 44.1354464197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '37ec68caf6257d989be2f04b6d05f73651e1a60e',
#    'name': 'استراحة الشريف حسين ال طالب',
#    'place_id': 'ChIJaSvV9RXr_hURepW7hCXK8Ks',
#    'plus_code': {'compound_code': 'F4MP+QM Najran Saudi Arabia',
#     'global_code': '7H96F4MP+QM'},
#    'rating': 5,
#    'reference': 'ChIJaSvV9RXr_hURepW7hCXK8Ks',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '7968، ابا لسعود، نجران 66277 3076،'},
#   {'geometry': {'location': {'lat': 17.4924586, 'lng': 44.1421206},
#     'viewport': {'northeast': {'lat': 17.4935606302915,
#       'lng': 44.1432798802915},
#      'southwest': {'lat': 17.4908626697085, 'lng': 44.1405819197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'f359dd716f08ad922ab6fe6cba258358be968eb5',
#    'name': 'آل قَصمان بالحارث',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJxxlwY23r_hURkL68ElMtKVA',
#    'plus_code': {'compound_code': 'F4RR+XR Najran Saudi Arabia',
#     'global_code': '7H96F4RR+XR'},
#    'reference': 'ChIJxxlwY23r_hURkL68ElMtKVA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '8781, ABA Lasaud, Najran 66277 3687'},
#   {'geometry': {'location': {'lat': 17.50231849999999, 'lng': 44.1366415},
#     'viewport': {'northeast': {'lat': 17.5036919802915,
#       'lng': 44.13809203029149},
#      'southwest': {'lat': 17.5009940197085, 'lng': 44.13539406970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '9a2aa5afbd2ee28a94c446ac62514e86860c8288',
#    'name': 'ديوانية ال سوار',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106901416232031724111">Black Epitaph</a>'],
#      'photo_reference': 'CmRaAAAA7vyafVH2bh_DWy0AU3xpe01wViwtQPNYKRR6SyAcSjLY5OuPUik1QKfyiUKA3S-9GJ0WvUwJhk34a-f8QjRClRwMUMDdZuzDsASDgPYWv2i-VO0693RmKSNtYzG7vKh6EhDU_kBNJBcETp6Zz1TBbRA6GhRoy4QGMksnKSdAh6zDJcuMdeEt0A',
#      'width': 1280}],
#    'place_id': 'ChIJL0KR-Afr_hURb4uoPbnaEbU',
#    'plus_code': {'compound_code': 'G42P+WM Najran Saudi Arabia',
#     'global_code': '7H96G42P+WM'},
#    'rating': 4.2,
#    'reference': 'ChIJL0KR-Afr_hURb4uoPbnaEbU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 19,
#    'vicinity': 'Saudi Arabia'},
#   {'geometry': {'location': {'lat': 17.47515, 'lng': 44.134679},
#     'viewport': {'northeast': {'lat': 17.47659108029151,
#       'lng': 44.13645028029149},
#      'southwest': {'lat': 17.4738931197085, 'lng': 44.1337523197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '9663fac41f7f88aae15e9165c2a0a5f79085c153',
#    'name': 'منتج الوادي .',
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114685047933334406192">ALI QABQAB</a>'],
#      'photo_reference': 'CmRaAAAA3MhPJyo6felNydPCV6bUtdRXkD5MX3Bdg7wnNgXKgIkHFysBWV-cRY0IaEMtsT_G6FoFbjIgVJn-6JgtFRtALenup_-XjvL-0KvGgFHxNC-rdHEvMSbc8fx91hd8wbBIEhDPaZOnz4d5VBWcXnKpWlDIGhS9QKchvSWuWREfi9u-ajnvx9xCWA',
#      'width': 4032}],
#    'place_id': 'ChIJ7UiJB5Hr_hURnixfbLI7uW0',
#    'plus_code': {'compound_code': 'F4GM+3V Aljurbah Saudi Arabia',
#     'global_code': '7H96F4GM+3V'},
#    'rating': 4.5,
#    'reference': 'ChIJ7UiJB5Hr_hURnixfbLI7uW0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 21,
#    'vicinity': '4139، الجربة، نجران 66291 7957،'},
#   {'geometry': {'location': {'lat': 17.4727212, 'lng': 44.1328898},
#     'viewport': {'northeast': {'lat': 17.4740979802915,
#       'lng': 44.1343477302915},
#      'southwest': {'lat': 17.4714000197085, 'lng': 44.1316497697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '6da8ec61e84c7981eb0bbadd3f669a82625e65ca',
#    'name': 'استراحة الجود',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105389626318877841597">ابو نهار ابو سعود</a>'],
#      'photo_reference': 'CmRZAAAAoEAQhWqibZ-yzdPH-HwQfnn9P--9ywqM9mEKJI5--EDq4X18UaVR-egZYolXHQYyT06ocpaIIpQqWHazCssPvub_Kt4wU9oGpn1hnA-0-dO-DJFDzuReOqiwyiGB9cKLEhBpHJY3P4apTGjyn6NArF0gGhQnLfS1RDz2ZUcEVK9if71vPLLFFg',
#      'width': 960}],
#    'place_id': 'ChIJ1_o38Hzr_hURwNv4_nujb08',
#    'plus_code': {'compound_code': 'F4FM+35 Najran Saudi Arabia',
#     'global_code': '7H96F4FM+35'},
#    'rating': 4.2,
#    'reference': 'ChIJ1_o38Hzr_hURwNv4_nujb08',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 34,
#    'vicinity': 'الجربة, Najran'},
#   {'geometry': {'location': {'lat': 17.4718539, 'lng': 44.1331221},
#     'viewport': {'northeast': {'lat': 17.4732319802915,
#       'lng': 44.1345851802915},
#      'southwest': {'lat': 17.4705340197085, 'lng': 44.1318872197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'dd1d77184d4a3084253e933f93e72862c9449776',
#    'name': 'إستراحة النجوم ال شهي',
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105918517711240674516">gray m</a>'],
#      'photo_reference': 'CmRaAAAAZEZlHHBA-lrhZftSynkmYL0YZHU-bXL0cMquvq5fqL8QyhLu-SAuwuejCPGeCrVdCZLL9jkwTIyfV4LE7B-gIf5IC9UWbtAJJ3BdOazCf3rMUoAhXyvRnRhg6uQiW3ZsEhARV7XwOObKFplIaOy-la6iGhTLeXYleI5Zh6xMtAT5pdDtFYDgbw',
#      'width': 3120}],
#    'place_id': 'ChIJ288Gi3nr_hUR_VULOxDyADs',
#    'plus_code': {'compound_code': 'F4CM+P6 Aljurbah Saudi Arabia',
#     'global_code': '7H96F4CM+P6'},
#    'rating': 4.3,
#    'reference': 'ChIJ288Gi3nr_hUR_VULOxDyADs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 44,
#    'vicinity': 'Saudi Arabia'},
#   {'geometry': {'location': {'lat': 17.4731557, 'lng': 44.1453928},
#     'viewport': {'northeast': {'lat': 17.4745046802915,
#       'lng': 44.14674178029149},
#      'southwest': {'lat': 17.4718067197085, 'lng': 44.14404381970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '762da18252cb91ab5b0b778f2c477d448a8dd1bc',
#    'name': 'السرحه',
#    'place_id': 'ChIJabIFdsbr_hUR4PleUFlAeq4',
#    'plus_code': {'compound_code': 'F4FW+75 Aljurbah Saudi Arabia',
#     'global_code': '7H96F4FW+75'},
#    'rating': 1.8,
#    'reference': 'ChIJabIFdsbr_hUR4PleUFlAeq4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': '4012, Al Jurbah, Najran 66277 6682'},
#   {'geometry': {'location': {'lat': 17.4669998, 'lng': 44.1278673},
#     'viewport': {'northeast': {'lat': 17.4686536802915,
#       'lng': 44.1290430302915},
#      'southwest': {'lat': 17.4659557197085, 'lng': 44.1263450697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/camping-71.png',
#    'id': '6c391c57877140076d05cfad322152dd74737c49',
#    'name': 'استراحة اغادير 1 للايجار اليومي',
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118083910357776871775">Hussin mohammad alyame</a>'],
#      'photo_reference': 'CmRaAAAA3UEFZPO-wlC3v55uYPknK0Yvp5FfM2eI5areF5GyHtgqujQgGqjpQJz-gOJgV4gCPfz3Rs450yxXyIG54af-1PGkNveCbeYlS73KnTwYMnx-o9DOsYEGjzXoaMni5l-pEhDj9AB2rUgTuy5M17zTusUjGhR9rsP1stmyPHkZTH5YZRNSQk2Kiw',
#      'width': 960}],
#    'place_id': 'ChIJUffWWL3r_hURYqcNp0Y012k',
#    'plus_code': {'compound_code': 'F48H+Q4 Aljurbah Saudi Arabia',
#     'global_code': '7H96F48H+Q4'},
#    'rating': 4.3,
#    'reference': 'ChIJUffWWL3r_hURYqcNp0Y012k',
#    'scope': 'GOOGLE',
#    'types': ['campground',
#     'lodging',
#     'park',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Saudi Arabia'},
#   {'geometry': {'location': {'lat': 17.4687866, 'lng': 44.11707879999999},
#     'viewport': {'northeast': {'lat': 17.4701889802915,
#       'lng': 44.1184379302915},
#      'southwest': {'lat': 17.4674910197085, 'lng': 44.1157399697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'f4a82066e23222311bb36a6c424b4e993d2cf3d2',
#    'name': 'ال غرزان',
#    'photos': [{'height': 1200,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110793441163171999244">رياح الريف Saudi Arabia</a>'],
#      'photo_reference': 'CmRaAAAAIdC1Gmfe0mpd3X3xMfC6O2Lugxiqof0rOlzDZtVIs-nhBoIt2uab4X6bnv4WwTOQwF_qWMYy72wPqKiTSX8reGm7LJIhEJyRf6--QAFPtyqwOjMzIws8YC7Qzp2SAwhgEhCJo4eKrTmqX0I8dLAzQVHfGhS5ryFi7nm3FgryRjVUfqxZVh5Kcw',
#      'width': 900}],
#    'place_id': 'ChIJ-e5Aw4Tr_hUR5cw-UXrZjXE',
#    'plus_code': {'compound_code': "F498+GR Aba as Su'ud Saudi Arabia",
#     'global_code': '7H96F498+GR'},
#    'rating': 5,
#    'reference': 'ChIJ-e5Aw4Tr_hUR5cw-UXrZjXE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': '4747، الحضن، نجران 66292 7529،'},
#   {'geometry': {'location': {'lat': 17.479206, 'lng': 44.15687199999999},
#     'viewport': {'northeast': {'lat': 17.4803984302915,
#       'lng': 44.15767393029149},
#      'southwest': {'lat': 17.47770046970849, 'lng': 44.1549759697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '68fa884824efd6394e747caadd5189d5ddc4844b',
#    'name': 'حي ال عميرة',
#    'photos': [{'height': 4608,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106912958531243805261">Nass Mod</a>'],
#      'photo_reference': 'CmRaAAAAlScNaiYd2PSLmhwcFaViuDkLY6463-MgDQQ4W0AXKg257z1CJVxtMPQYfX0rqATpyXqQEfIKB-iwbLf7pdeG0Fw96biYkafsMYrZ1H6btzJJgv4V51t-iu-HdYqf426WEhAn5VyHehmSNGgbtVVi9MO8GhTpFxNEJKJHxetd3Mhw3bvvv4lo9Q',
#      'width': 3456}],
#    'place_id': 'ChIJXapxelnr_hURykbxIwkdjLU',
#    'plus_code': {'compound_code': 'F5H4+MP Najran Saudi Arabia',
#     'global_code': '7H96F5H4+MP'},
#    'rating': 4.2,
#    'reference': 'ChIJXapxelnr_hURykbxIwkdjLU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': '2612 القابل،, 6803, Najran'},
#   {'geometry': {'location': {'lat': 17.4856299, 'lng': 44.15889960000001},
#     'viewport': {'northeast': {'lat': 17.4869525802915, 'lng': 44.16462735},
#      'southwest': {'lat': 17.4842546197085, 'lng': 44.15699035000002}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '6b56955d06f5da20963cd4cd3f1f2dab5d9af21c',
#    'name': 'هادي زاهر',
#    'place_id': 'ChIJScWO3ebr_hURLLclP5QvRpU',
#    'plus_code': {'compound_code': 'F5P5+7H Alqabil, Najran Saudi Arabia',
#     'global_code': '7H96F5P5+7H'},
#    'reference': 'ChIJScWO3ebr_hURLLclP5QvRpU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '66275،'},
#   {'geometry': {'location': {'lat': 17.4621427, 'lng': 44.1208074},
#     'viewport': {'northeast': {'lat': 17.4632277302915,
#       'lng': 44.1222199802915},
#      'southwest': {'lat': 17.46052976970849, 'lng': 44.1195220197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'fc342238a4cd4f89dcacb43fac5e5e0d28224d37',
#    'name': 'ضيافة / علي بن سعيد ال هطيل',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJsz_emAzt_hURMWMgpTXN0D8',
#    'plus_code': {'compound_code': "F46C+V8 Aba as Su'ud Saudi Arabia",
#     'global_code': '7H96F46C+V8'},
#    'rating': 5,
#    'reference': 'ChIJsz_emAzt_hURMWMgpTXN0D8',
#    'scope': 'GOOGLE',
#    'types': ['museum', 'lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '6466، الحضن، نجران 66291 2798،'},
#   {'geometry': {'location': {'lat': 17.4602899, 'lng': 44.1277641},
#     'viewport': {'northeast': {'lat': 17.4614463802915,
#       'lng': 44.1291523302915},
#      'southwest': {'lat': 17.4587484197085, 'lng': 44.1264543697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '6fbd98a2a4dc20b86a250ff1c484616764eff001',
#    'name': 'القصرالتاريخي للحاج مهدي ال بليه لسلوم',
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109145149668778697803">lthdie teerb</a>'],
#      'photo_reference': 'CmRaAAAAdLCzvzcODWR3cE47fgbRGDKrRTyEorBHsooCu84e138tliP4_aO-aUgf7bnlprWwqQiyBQdGHnQyZYXnFFdfPZj-mK5OA37wKXTq9IhTnOSBlnIL-vUYxECkwKN7jci-EhCrP5KFBFjYd20b_7QsHXlQGhSaDr0DvlmaSZ95JfFrwJ0UmifDOw',
#      'width': 5312}],
#    'place_id': 'ChIJDc-dVkXt_hUR-ERwYeHmJrw',
#    'plus_code': {'compound_code': "F46H+44 Alhadn, Aba as Su'ud Saudi Arabia",
#     'global_code': '7H96F46H+44'},
#    'reference': 'ChIJDc-dVkXt_hUR-ERwYeHmJrw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Saudi Arabia'},
#   {'geometry': {'location': {'lat': 17.4592127, 'lng': 44.1216265},
#     'viewport': {'northeast': {'lat': 17.4603400802915,
#       'lng': 44.1230214302915},
#      'southwest': {'lat': 17.4576421197085, 'lng': 44.1203234697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '5317d70590d7266850c134bc1dbe401c9e65a7b8',
#    'name': 'سكن لإجار',
#    'place_id': 'ChIJRR0Vh2nt_hURrvrLTjgpy3A',
#    'plus_code': {'compound_code': "F45C+MM Aba as Su'ud Saudi Arabia",
#     'global_code': '7H96F45C+MM'},
#    'reference': 'ChIJRR0Vh2nt_hURrvrLTjgpy3A',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Saudi Arabia'},
#   {'geometry': {'location': {'lat': 17.4636275, 'lng': 44.11066509999999},
#     'viewport': {'northeast': {'lat': 17.4650050302915,
#       'lng': 44.11162273029149},
#      'southwest': {'lat': 17.4623070697085, 'lng': 44.10892476970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '9abd73465767b0369e83bd6964827be745a52bf2',
#    'name': 'ديوانية ال غفينة',
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116386024334755311615">Mohammed Ghofinah</a>'],
#      'photo_reference': 'CmRaAAAA1YrLLRWlFr1z_HjVJ5b9aHNw63toVODDovfZE6h06PN9qWCcngP00IdqyfuiYgX8m1lJwthGi4ZVSPwh0zjyLB000ceeeQsixTGrhGL0tQGRG58lINQESPsn58KC0gdkEhA3wN6faW5pnrTURgNqdWoKGhQXFr5wE-eJrko7qqvWoz4jW78kpw',
#      'width': 1080}],
#    'place_id': 'ChIJ5fAyjMvt_hURLnF4UEJLio8',
#    'plus_code': {'compound_code': "F476+F7 Aba as Su'ud Saudi Arabia",
#     'global_code': '7H96F476+F7'},
#    'rating': 5,
#    'reference': 'ChIJ5fAyjMvt_hURLnF4UEJLio8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': ''},
#   {'geometry': {'location': {'lat': 17.4631291, 'lng': 44.1096576},
#     'viewport': {'northeast': {'lat': 17.4644775302915,
#       'lng': 44.1110611802915},
#      'southwest': {'lat': 17.4617795697085, 'lng': 44.1083632197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '7fb5a86545d0ff9f642cbcca81b6d7aa4aa93e42',
#    'name': 'ضيافة آل حيدر',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107649311841755011008">ضيافة آل حيدر</a>'],
#      'photo_reference': 'CmRaAAAAd8Tmu_a3KW4ms_fngTdhwc9lK3jWymuE0QKsQzagMOVuP5aaplXUnI6Xz-ZQ4Q2FFSlPQ7BHVoHG3fZUcVcnm4kKtMSVJoQxRRZwHS7yPlRd01bi3Zw0uv7DiU8ggloyEhDEChIvD-uWJQVgABRdnTo7GhTyZCsUO2fFJhwfjGPW2j_naUAtRQ',
#      'width': 3024}],
#    'place_id': 'ChIJf4zIJOft_hUReWwKDYkQYnM',
#    'plus_code': {'compound_code': 'F475+7V Najran Saudi Arabia',
#     'global_code': '7H96F475+7V'},
#    'rating': 5,
#    'reference': 'ChIJf4zIJOft_hUReWwKDYkQYnM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 8,
#    'vicinity': 'الامير سلطان, Najran'}],
#  'status': 'OK'}

# %%
# the variable city_hotel should be a list that holds all city hotels names
city_hotel = response["results"][0]["name"]
city_hotel
# Out:
# 'محمد هادي ال فطيح'

# %%
hotel_df["Hotel_Name"] = city_hotel
hotel_df
# Out:
# C:\Users\dofwj\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                       city  Max_Temperature  latitude  longitude  humidity  \
# 13                  najran            77.00     17.49      44.13        50
# 140                 kamthi            82.40     21.23      79.20        39
# 157                 laguna            81.00     38.42    -121.42        38
# 266           saint george            73.99     37.10    -113.58        21
# 279             ongandjera            79.45    -17.88      15.07        23
# 297                 ruston            73.40     32.52     -92.64        20
# 318                  avera            72.00     33.19     -82.53        28
# 320        puerto quijarro            76.23    -17.78     -57.77        46
# 353                 taltal            70.52    -25.40     -70.48        59
# 414  mayor pablo lagerenza            81.75    -19.93     -60.77        24
# 480                tambura            77.34      5.60      27.47        48
# 520              henderson            79.00     36.04    -114.98        16
# 522              mongoumba            81.16      3.64      18.59        51
#
#      clouds  wind country        date         Hotel_Name
# 13        5  6.93      SA  1587073874  محمد هادي ال فطيح
# 140      20  3.36      IN  1587074147  محمد هادي ال فطيح
# 157       1  4.03      US  1587074150  محمد هادي ال فطيح
# 266       1  4.70      US  1587073954  محمد هادي ال فطيح
# 279       0  3.62     NaN  1587074175  محمد هادي ال فطيح
# 297       1  6.93      US  1587074178  محمد هادي ال فطيح
# 318       1  3.36      US  1587074182  محمد هادي ال فطيح
# 320       0  4.59      BO  1587074182  محمد هادي ال فطيح
# 353       7  6.82      CL  1587074091  محمد هادي ال فطيح
# 414       0  5.91      PY  1587074197  محمد هادي ال فطيح
# 480       5  2.30      SS  1587074206  محمد هادي ال فطيح
# 520       1  3.36      US  1587074212  محمد هادي ال فطيح
# 522       5  1.23      CF  1587074213  محمد هادي ال فطيح

# %%
# NOTE: Do not change any of the code in this cell
locations = hotel_df[["latitude", "longitude"]]
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel_Name}</dd>
<dt>City</dt><dd>{city}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations ,info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
